# %%
from pyplotdesigner.core.design_loader import load_figure_from_b64

# %% [markdown]
# ## click on the 'Import/Export' buttron at the top right of the gui and copy the string

# %% [markdown]
# <img src="example_gui.png">

# %%
import_string = "..."

fig, axes = load_figure_from_b64(import_string)

left_panel_axis = axes['left_panel']
center_left_axis = axes['center_left']
upper_left_panel_axis = axes['upper_left_panel']
right_axis = axes['right']
wide_axis = axes['wide']

wide_axis.plot([0, 1, 2], [0, 1, 0])
